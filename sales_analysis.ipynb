# %% [markdown]
# <a href="https://colab.research.google.com/github/SIVASHANKARI04/Customer-Purchase-Analytics/blob/main/sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/shopping_trends.csv")

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# #1.What are the columns, data types, and shape of the dataset?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.shape
# Out:
# (3900, 19)

# %% [markdown]
# #2.Are there any missing values? If so, which columns have them?

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# #3.What are the minimum, maximum, mean, and median values for numerical columns (e.g., purchase amount)?

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.median(numeric_only=True)
# Out:
# Customer ID              1950.5
# Age                        44.0
# Purchase Amount (USD)      60.0
# Review Rating               3.7
# Previous Purchases         25.0
# dtype: float64

# %% [markdown]
# #4.How many unique values are there in each categorical column?

# %%
df["Category"].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
df["Category"].nunique()
# Out:
# 4

# %% [markdown]
# #5.Find all purchases greater than a specific amount (e.g., $95).

# %%
df[df["Purchase Amount (USD)"] > 95].loc[:,["Purchase Amount (USD)"]]
# Out:
#       Purchase Amount (USD)
# 8                        97
# 42                      100
# 79                       96
# 81                       96
# 91                       99
# ...                     ...
# 3819                     99
# 3837                    100
# 3864                     99
# 3871                     97
# 3877                     96
#
# [248 rows x 1 columns]

# %% [markdown]
# #6.Filter data for customers from a specific location or category

# %%
df[(df["Location"]=="Oregon") & (df["Category"]=="Clothing")].loc[:,["Location","Category"]]
# Out:
#      Location  Category
# 4      Oregon  Clothing
# 304    Oregon  Clothing
# 335    Oregon  Clothing
# 518    Oregon  Clothing
# 643    Oregon  Clothing
# 713    Oregon  Clothing
# 855    Oregon  Clothing
# 934    Oregon  Clothing
# 1044   Oregon  Clothing
# 1176   Oregon  Clothing
# 1180   Oregon  Clothing
# 1215   Oregon  Clothing
# 1267   Oregon  Clothing
# 1283   Oregon  Clothing
# 1353   Oregon  Clothing
# 1528   Oregon  Clothing
# 1677   Oregon  Clothing
# 2101   Oregon  Clothing
# 2162   Oregon  Clothing
# 2204   Oregon  Clothing
# 2396   Oregon  Clothing
# 2433   Oregon  Clothing
# 2650   Oregon  Clothing
# 2830   Oregon  Clothing
# 2915   Oregon  Clothing
# 3003   Oregon  Clothing
# 3073   Oregon  Clothing
# 3105   Oregon  Clothing
# 3108   Oregon  Clothing
# 3167   Oregon  Clothing
# 3242   Oregon  Clothing
# 3281   Oregon  Clothing
# 3390   Oregon  Clothing
# 3426   Oregon  Clothing
# 3500   Oregon  Clothing
# 3549   Oregon  Clothing
# 3712   Oregon  Clothing

# %% [markdown]
# #7.What is the total purchase amount grouped by category?

# %%
df.groupby("Category")['Purchase Amount (USD)'].sum()
# Out:
# Category
# Accessories     74200
# Clothing       104264
# Footwear        36093
# Outerwear       18524
# Name: Purchase Amount (USD), dtype: int64

# %% [markdown]
# #8.Find the average purchase amount per product category.

# %%
df.groupby("Category")['Purchase Amount (USD)'].mean()
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# #9.Retrieve rows where the category is either "Accessories" or"Outerwear".

# %%
df[(df["Category"]=="Accessories") | (df["Category"]=="Outerwear")].value_counts()
# Out:
# Customer ID  Age  Gender  Item Purchased  Category     Purchase Amount (USD)  Location        Size  Color     Season  Review Rating  Subscription Status  Payment Method  Shipping Type   Discount Applied  Promo Code Used  Previous Purchases  Preferred Payment Method  Frequency of Purchases
# 9            26   Male    Coat            Outerwear    97                     West Virginia   L     Silver    Summer  2.6            Yes                  Venmo           Express         Yes               Yes              8                   Venmo                     Annually                  1
# 2544         27   Male    Scarf           Accessories  56                     West Virginia   L     Peach     Spring  2.7            No                   Debit Card      Next Day Air    No                No               30                  PayPal                    Bi-Weekly                 1
# ...

# %% [markdown]
# #10.Sort the dataset by purchase_amount in descending order.

# %%
df.sort_values(by=["Purchase Amount (USD)"],ascending=False)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2842         2843   28  Female           Coat    Outerwear
# 95             96   37    Male       Sneakers     Footwear
# 581           582   32    Male        Sweater     Clothing
# 1421         1422   68    Male          Dress     Clothing
# 3837         3838   45  Female         Hoodie     Clothing
# ...           ...  ...     ...            ...          ...
# 1704         1705   56    Male       Sneakers     Footwear
# 294           295   70    Male          Skirt     Clothing
# 977           978   20    Male           Belt  Accessories
# 508           509   27    Male        Jewelry  Accessories
# 2798         2799   52  Female         Hoodie     Clothing
#
#       Purchase Amount (USD)      Location Size     Color  Season  \
# 2842                    100       Arizona    L     Green    Fall
# 95                      100      Missouri    L      Pink    Fall
# ...
